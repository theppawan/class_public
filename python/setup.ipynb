# %%
# !python -m pip -V
# Out:
# pip 25.3 from /Users/chakkritk/myUniverse/research/research_tools/class_quintom/.qtm/lib/python3.14/site-packages/pip (python 3.14)

# %%
# !python -m pip uninstall -y classy
# Out:
# Found existing installation: classy 3.3.1.0
# Uninstalling classy-3.3.1.0:
#   Successfully uninstalled classy-3.3.1.0

# %%
# !find "$HOME/Library/Python/3.14/lib/python/site-packages" -maxdepth 1 -name "classy*.so" -print -delete 2>/dev/null || true

# %%
# !rm -rf build *.so *.c *.cpp *.o *.pyc __pycache__
# Out:
# zsh:1: no matches found: *.c

# %%
# !python -m pip install -U pip setuptools wheel cython

# %%
# !pip install -e . --no-build-isolation -v
# Out:
# Using pip 25.3 from /Users/chakkritk/myUniverse/research/research_tools/class_quintom/.qtm/lib/python3.14/site-packages/pip (python 3.14)
# Obtaining file:///Users/chakkritk/myUniverse/research/research_tools/class_quintom/class_public/python
#   Checking if build backend supports build_editable ...   Running command Checking if build backend supports build_editable
# done
#   Preparing editable metadata (pyproject.toml) ...   Running command Preparing editable metadata (pyproject.toml)
#   running dist_info
#   creating /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6fhdl647/classy.egg-info
#   writing /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6fhdl647/classy.egg-info/PKG-INFO
#   writing dependency_links to /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6fhdl647/classy.egg-info/dependency_links.txt
# ...

# %%
# !python setup.py build_ext --inplace --force
# Out:
# running build_ext
# [1/1] Cythonizing /Users/chakkritk/myUniverse/research/research_tools/class_quintom/class_public/python/../python/classy.pyx
# ...
# building 'classy' extension
# ...

# %%
# !python -m pip install -e . --no-build-isolation -v
# Out:
# Using pip 25.3 from /Users/chakkritk/myUniverse/research/research_tools/class_quintom/.qtm/lib/python3.14/site-packages/pip (python 3.14)
# Obtaining file:///Users/chakkritk/myUniverse/research/research_tools/class_quintom/class_public/python
#   Checking if build backend supports build_editable ...   Running command Checking if build backend supports build_editable
# done
#   Preparing editable metadata (pyproject.toml) ...   Running command Preparing editable metadata (pyproject.toml)
#   running dist_info
#   creating /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6s1r6a5r/classy.egg-info
#   writing /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6s1r6a5r/classy.egg-info/PKG-INFO
#   writing dependency_links to /private/var/folders/3w/j515plxn1nsbbjp4n13dthsr0000gn/T/pip-modern-metadata-6s1r6a5r/classy.egg-info/dependency_links.txt
# ...
